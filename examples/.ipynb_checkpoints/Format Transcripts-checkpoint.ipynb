# %%
import os, re, glob, numpy
import pandas as pd

INPUT_PATH = '/Users/nduran/Desktop/GitProjects/align-linguistic-alignment/examples/CHILDES/transcripts/'
OPUT_PATH = '/Users/nduran/Desktop/GitProjects/align-linguistic-alignment/examples/CHILDES/childes-original/'

file_list = os.listdir(INPUT_PATH)
for fileName in file_list:  
    getFilepart = fileName.split(".")
    outname = OPUT_PATH + "time" + getFilepart[0] + "-cond" + "1" + ".txt"
    fh = open(outname, "w")
    fh.writelines(["participant","\t","content","\n"])
#     df = pd.read_csv(INPUT_PATH + fileName, sep='\t',header=None) 
    df = pd.read_csv(INPUT_PATH + fileName, sep='\t') 
    for value in df.values:  
        value = value.tolist()
        line = re.sub('1cgv', 'cgv', value[0])
        line = re.sub('1kid', 'kid', line)
        line1 = line.split(" ")
        line2 = line1[2]
        line3 = line1[3:]
        line4 = (" ".join(line3))        
        finalList = [line2,"\t",line4,"\n"]
        fh.writelines(finalList)
    fh.close()

# %%
import os, re, glob, numpy
import pandas as pd

INPUT_PATH = '/Users/nduran/Desktop/GitProjects/align-linguistic-alignment/examples/CALL_FRIEND/'
OPUT_PATH = '/Users/nduran/Desktop/GitProjects/align-linguistic-alignment/examples/CALL_FRIEND/callfriend-original/'

file_list = os.listdir(INPUT_PATH)
for fileName in file_list:  
    if ".txt" in fileName:
        getFilepart = fileName.split(".")
    #     outname = OPUT_PATH + "time" + getFilepart[0] + "-cond" + "1" + ".txt"
    #     fh = open(outname, "w")
#         fh.writelines(["participant","\t","content","\n"])
    #     df = pd.read_csv(INPUT_PATH + fileName, sep='\t',header=None) 
        df = pd.read_csv(INPUT_PATH + fileName, sep='\t',squeeze=True) 
        
#         for value in df.values:  
#             value = value.tolist()
#             print value
#             line = re.sub('1cgv', 'cgv', value[0])
#             line = re.sub('1kid', 'kid', line)
#             line1 = line.split(" ")
#             line2 = line1[2]
#             line3 = line1[3:]
#             line4 = (" ".join(line3))        
#             finalList = [line2,"\t",line4,"\n"]
            
            
            
    #         fh.writelines(finalList)
    #     fh.close()
# Out:
# 0                                              M2: hello
# 1                                              M1: i yup
# 2                                                 M1: aa
# 3                                                  M1: i
# 4                                    M2: i so no sex now
# 5                                                    M2:
# 6                    M1: yeah I didnt know about that um
# 7                M1: publically released part part there
# 8                                                  M2: i
# 9                                        M1: so no names
# 10                                                   M2:
# 11                                                 M2: i
# 12                                          M2: no names
# 13                                   M1: i no last names
# 14                                          M1: no names
# 15                                                   M1:
# 16                                   M2: no names at all
# 17       M1: oh well obviously were going to have to h...
# 18                                  M2: but no lastnames
# 19                                               M1: yup
# 20       M2: i unless you want to be a dick to somebod...
# 21                                                   M2:
# 22                                                 M1: i
# 23                                               M2: i i
# 24             M1: yeah this person did this to this and
# 25                       M1: that person did that person
# 26             M2: yeah that that was Ken Ferguson there
# 27                                    M2: yeah and he uh
# 28       M2: i he uh masturbated in front of a one tho...
# 29                                                   M1:
#                               ...
# 1212                                        M2: you lose
# 1213                                                 M2:
# 1214     M1: that would move me up from a three five t...
# 1215                    M1: thats a big difference to me
# 1216                                M1: personality wise
# 1217                                                 M2:
# 1218     M1: it really doesnt change my overall G P A ...
# 1219                                                 M2:
# 1220              M1: but its just like my lone Bl in it
# 1221     M1: shit three seven sounds so much better than
# 1222                                                 M2:
# 1223                                      M1: three five
# 1224                                                 M2:
# 1225     M1: and I Id be more eligible for the deans l...
# 1226     M2: yeah I got a three five for this semester...
# 1227                                             M1: uuh
# 1228                   M2: but with my um my other class
# 1229     M1: cause you know I have like a Bl plus and ...
# 1230            M2: but my other class I had an Al minus
# 1231     M2: for my first part of the um the journals ...
# 1232                                             M1: uuh
# 1233        M2: i so I should have an Al in the overalls
# 1234                                M2: for the journals
# 1235                                            M1: yeah
# 1236     M2: and ah my paper I turned in as least my r...
# 1237                                             M1: uuh
# 1238                                          M2: so now
# 1239                                        M2: you know
# 1240     M1: Im sure once I do what you know what he s...
# 1241                                    M1: you know End
# Name:  M1: , Length: 1242, dtype: object
# 0                                         SON: hello ma
# 1                                    MA: yeah mazel tov
# 2                                        SON: mazel tov
# 3                           MA: last night was the Vort
# 4                                                  SON:
# 5                                                SON: x
# 6                         MA: so wednesday night is the
# 7                                                  SON:
# 8                                 MA: you could come in
# 9       SON: I have a I have to speak to Tatie becaus...
# 10                             SON: and he told me that
# 11                                           MA: uh huh
# 12      SON: well pass by Monroe we could pick up Est...
# 13                                                  MA:
# 14                                  MA: okay one second
# 15               SON: so thats what Im going to ask him
# 16                                                  MA:
# 17                                            EPH: yeah
# 18                                      MA: I cant hear
# 19                                              EPH: oh
# 20                                                  MA:
# 21                                                  MA:
# 22                                   EPH: hello Natanel
# 23                                            SON: yeah
# 24                             EPH: mazel tov mazel tov
# 25                                       SON: mazel tov
# 26                                                 EPH:
# 27                                 SON: yeah thats true
# 28                                             SON: wha
# 29                                               EPH: a
#                              ...
# 236                    EPH: Hes coming to Bourough Park
# 237                           SON: yeah I think so yeah
# 238                                         EPH: Uh huh
# 239                                SON: to where I live
# 240     EPH: ok very good Anything uh anything you wa...
# 241                            SON: glasses broke today
# 242                       EPH: your broke What happened
# 243     SON: yeah and I mean you could just get a new...
# 244             EPH: uh huh Ok Bring all the parts home
# 245                                           SON: yeah
# 246                                           EPH: okay
# 247                                           SON: okay
# 248     EPH: okay so well see you im yirtse hashemsy ...
# 249                                           SON: okay
# 250     EPH: the Vortsy is in Flatbush at East sevent...
# 251                                         SON: a hall
# 252                          EPH: yeah a hall in a shul
# 253                  SON: and then little Chaya is nice
# 254                               EPH: chayas beautiful
# 255                               EPH: we have pictures
# 256                         EPH: They took pictures huh
# 257                        SON: Oh is it by their house
# 258                      SON: what is it by their house
# 259                                       EPH: in house
# 260     EPH: yeah Ill tell you everything when you co...
# 261                                           SON: Okay
# 262                                           EPH: Yeah
# 263     EPH: Zaisy gezuntsy were looking forward to s...
# 264                                       SON: okay bye
# 265                                EPH: kol tuv bye bye
# Name:  MA: hello , Length: 266, dtype: object
# 0                                   M1: do you get paid
# 1       M1: uhyou youre do ing a ser vice to science ...
# 2                                    M1: i well exactly
# 3                       M1: I mean youre in engineering
# 4                            M1: you like science right
# 5                                                 M1: i
# 6                                    M1: so so whats up
# 7                                                   M1:
# 8                M1: i so you are you going out tonight
# 9                   M1: you know whats going on tonight
# 10                                      M1: I dont know
# 11                                            M1: thats
# 12               M1: the Love Dogs already drinking but
# 13                M1: i we dont know where to go to yet
# 14                                                M1: i
# 15              M1: well Im mean Ive only had two beers
# 16      M1: but uh hes had Josh has had about fourand...
# 17      M1: i even though we dont know if well actual...
# 18                                           M1: but uh
# 19                                             M1: okay
# 20      M1: see uh we just gotta pass like five minutes
# 21                                 M1: is that cool man
# 22       M1: you just gotta pass like five minutes away
# 23                                     M1: is that cool
# 24                          M1: yeah um yeah no problem
# 25                                                  M1:
# 26                                        M1: beautiful
# 27            M1: i so are you going out tomorrow night
# 28                                          M1: why not
# 29                                            M1: seven
#                              ...
# 245                                               M1: i
# 246          M1: cause like he was at dinner last night
# 247                                     M1: and he left
# 248                           M1: Cox and Greg Giordano
# 249     M1: like the next day today he asked me hes l...
# 250                                              M1: ih
# 251     M1: is is is Turp normally like that or is he...
# 252                                      M1: I was like
# 253                                   M1: no thats Turp
# 254                                                 M1:
# 255                                               M1: i
# 256                 M1: people just dont realize it but
# 257                           M1: i hes just that weird
# 258                                         M1: yeah uh
# 259                 M1: yeah I think the two minutes is
# 260                    M1: I I great ly appreciate this
# 261                                        M1: I me Ill
# 262     M1: Ill make sure we give you a call if were ...
# 263                      M1: and what time do you think
# 264                          M1: youre er ging tomorrow
# 265                                            M1: noon
# 266                                              M1: hm
# 267                              M1: noon or one or two
# 268                                               M1: i
# 269     M1: give me a call before you leave if you want
# 270                                   M1: I might be up
# 271                                       M1: cool dude
# 272                                   M1: thank s a lot
# 273                                             M1: Gus
# 274                                           M1: later
# Name:  M1: o kay , Length: 275, dtype: object
# 0             M1: whatt they didnt say that in the thing
# 1                                     M2: that was weird
# 2                                                    M2:
# 3                             M1: publically distributed
# 4                                     M2: that was weird
# 5                                  M1: I didnt read that
# 6                                                    M2:
# 7                                       M1: well the was
# 8            M2: okay well lets not talk about terrorism
# 9                                                 M1: no
# 10       M1: Janice was talking to one of her friends ...
# 11                                                   M2:
# 12       M1: oh you know if youre going to get pregnan...
# 13                                                   M1:
# 14                                                   M2:
# 15                                    M1: thats not good
# 16                                                   M2:
# 17                                    M1: did you see um
# 18                                 M1: we rented that uh
# 19       M1: one of those uh Tom Clancy movies with Ha...
# 20                 M1: the one where he goes to Columbia
# 21                              M1: did you see that one
# 22                                             M2: no no
# 23         M1: they had this little scene where the guys
# 24       M1: some guy in Columbia was using his cell p...
# 25                        M1: some other guy in Columbia
# 26                                            M2: uh huh
# 27         M1: and then you see this scene in Washington
# 28          M1: and then you see a bunch of antennas and
# 29                   M1: radar dishes and stuff and then
#                               ...
# 1112                                         F2: Ill try
# 1113                         F1: but I I heard your news
# 1114                                            F2: yeah
# 1115                            F1: second or third hand
# 1116                                                 F2:
# 1117                                                 F2:
# 1118                                  F1: thats exciting
# 1119     F2: yeah were very yeah were freaked out a li...
# 1120            F2: we have three and a half more months
# 1121                                             F1: wow
# 1122                  F1: thats still not very far is it
# 1123                                      F2: I know its
# 1124                                          F1: oh man
# 1125                                                 F2:
# 1126                                                 F1:
# 1127                               F2: I cant believe it
# 1128                      F2: I was miserable until like
# 1129     F2: the last couple of weeks have been good a...
# 1130                                      F1: physically
# 1131                                            F2: yeah
# 1132                                             F1: aha
# 1133     F2: I was really I had really bad morning sic...
# 1134                                          F1: oh gee
# 1135     F2: and um then I just had all sorts of aches...
# 1136     F1: and now youre starting to get past that tot
# 1137                          F2: yeah yeah but now like
# 1138     F2: Ive been the second trimesters supposed t...
# 1139                           F2: Im going in to the uh
# 1140                    F2: third trimester in two weeks
# 1141                                              F1: oh
# Name:  M2: , Length: 1142, dtype: object
# 0                                                   SAR:
# 1                                                 DEB: i
# 2                                  SAR: I have to get my
# 3              SAR: i let me uh switch phones one second
# 4                                              DEB: okay
# 5                                                   SAR:
# 6                                              SAR: Okay
# 7                                 SAR: sorry a bout that
# 8                                                   DEB:
# 9                                                 DEB: i
# 10                                                SAR: i
# 11                                       DEB: thats okay
# 12                                      DEB: how are you
# 13                                          SAR: Im good
# 14                                              DEB: how
# 15                                      SAR: how are you
# 16                                          DEB: Im okay
# 17                                                SAR: i
# 18                               SAR: whats up whats new
# 19       DEB: well Paul and I broke up Im sure youve h...
# 20                                        DEB: from Bryn
# 21                                          SAR: well uh
# 22                                               SAR: no
# 23                            SAR: its kind of confusing
# 24                         SAR: cant you guys on and off
# 25                      DEB: no were broken up broken up
# 26         DEB: he broke up with me like three weeks ago
# 27                                DEB: a month ago maybe
# 28          DEB: and i I mean we still seeing each other
# 29                                                  DEB:
#                               ...
# 1258     DEB: but its like my department hires people ...
# 1259     DEB: i they actually have a new place in Minn...
# 1260                     DEB: and they hire for them too
# 1261                                    SAR: diversified
# 1262                                                DEB:
# 1263     DEB: its like totally if I was into business ...
# 1264     DEB: this is the pharmaceutical industry is l...
# 1265               DEB: because its like totally booming
# 1266                                         SAR: really
# 1267                                 DEB: oh my god yeah
# 1268     DEB: and for some reason in Philadelphia area...
# 1269     DEB: like Merck and um and Smith Kline Beecha...
# 1270                         DEB: theyre all around here
# 1271                             SAR: theyre based there
# 1272                                           DEB: yeah
# 1273     DEB: well at least the corporate headquarters...
# 1274                                       DEB: i and uh
# 1275                                         SAR: ah hah
# 1276           DEB: and Squibb and different I dont know
# 1277                                     DEB: but anyway
# 1278                                           DEB: i so
# 1279                                            SAR: huh
# 1280                DEB: its its been really interesting
# 1281       DEB: I also help uh do all the research on um
# 1282          DEB: one of my bosses i is doing trying to
# 1283     DEB: I did this research on this article abou...
# 1284     DEB: like companies like how much kids sick d...
# 1285     DEB: how much time they give for i maternity ...
# 1286                                  DEB: how much i um
# 1287     DEB: you know whether they have day care cent...
# Name:  DEB: are you still there , Length: 1288, dtype: object
# 0                                               M1: okay
# 1                                               M2: yeah
# 2                                                 M2: aa
# 3                                       M1: oh all right
# 4                                  M2: a i um did you uh
# 5                        M2: did you send uh Kara the uh
# 6                                                 M2: uh
# 7                                               M2: yeah
# 8                                    M1: printer ribbons
# 9                                                M2: yup
# 10                                                 M2: a
# 11                                           M1: oh good
# 12                                                 M2: i
# 13                                               M1: you
# 14                                    M2: I sent them on
# 15       M1: did did did you send her the coffee grind...
# 16                                              M2: nope
# 17                                                   M1:
# 18                       M2: i well I was going to go up
# 19                                M2: and I was going to
# 20                                                M1: uh
# 21                            M2: visit her this weekend
# 22                                                M1: oh
# 23                                            M2: but um
# 24                                  M2: i ho lly had her
# 25                                            M2: her um
# 26                         M2: her operation on Thursday
# 27                                              M1: yeah
# 28                                                M1: oh
# 29              M2: so shes not in the greatest of moods
#                               ...
# 1192                            M2: Auto cad lite he had
# 1193     M2: i but still thats not too bad be cause I ...
# 1194         M2: i uh we can get lite through the school
# 1195                                         M1: oh yeah
# 1196     M1: I mean we would talk probably you know tw...
# 1197                                   M2: not even that
# 1198     M2: Ka ra can get an educational discount thr...
# 1199                                              M1: oh
# 1200                                         M1: oh okay
# 1201     M2: i as long as shes got a student I D card ...
# 1202                                         M1: oh okay
# 1203                                         M2: i o kay
# 1204                                              M2: um
# 1205     M2: so then yeah prob ably what Im going to d...
# 1206                                              M1: oh
# 1207                                       M1: all right
# 1208     M2: i um they just came out with a coup le ne...
# 1209                                               M2: i
# 1210                                              M1: oh
# 1211                M2: so Im going to put it to ge ther
# 1212                                      M2: i and then
# 1213     M2: one day when you come down we can put Aut...
# 1214     M2: or install it so when you come down you c...
# 1215     M2: i and see if its you know if its better w...
# 1216                                               M1: m
# 1217                    M2: well its going to be be tter
# 1218     M2: but you know if its any you know whizo ba...
# 1219                                               M2: i
# 1220                                            M1: yeah
# 1221     M2: i you know to think that if Im in the rig...
# Name:  M1: , Length: 1222, dtype: object
# 0               CLD: no way man Im not Im not involved
# 1                     CLD: I dont want myvoice on this
# 2                             CLR: you have to hang up
# 3                                    CLD: nah thats it
# 4                                     CLD: so whats up
# 5      CLR: hey um I uh called about uh some uh uh t...
# 6                                            CLD: yeah
# 7      CLR: and it looks like that it works out pret...
# 8                                           CLD: mhunh
# 9                          CLR: the the train business
# 10                                           CLD: yeah
# 11                         CLR: hey forget all of that
# 12                                        CLD: oh okay
# 13     CLR: god it that is really wild is that um yo...
# 14                                           CLD: yeah
# 15                                    CLR: from Denver
# 16                                                CLD:
# 17                                       CLR: to Boise
# 18                                          CLD: uhunh
# 19     CLR: and you have to only do that on a Thursd...
# 20                                             CLD: oh
# 21     CLR: or you can go from uh Denver to Portland...
# 22                                           CLD: okay
# 23                                         CLR: anyway
# 24                                            CLD: yup
# 25     CLR: it turns out that um Deb and Glenn are c...
# 26                                           CLD: okay
# 27      CLR: theyre not coming in until eight forty pm
# 28                                            CLD: mhm
# 29           CLR: but I can get a a decent neat flight
#                             ...
# 44     CLR: okay Deb Glenn leaves on the third Deb l...
# 45     CLR: and leave at two fifteen and arrive in D...
# 46                                           CLD: okay
# 47                                            CLR: unh
# 48                           CLD: yep that sounds good
# 49     CLR: okay Ill go ahead and uh confirm that bu...
# 50                                          CLD: great
# 51            CLR: so what else is going on down there
# 52     CLD: oh Im just watching Johnny Cochoran schm...
# 53                            CLR: yeah but hes guilty
# 54                                      CLD: you think
# 55         CLR: theyll come back with a guilty verdict
# 56                                   CLD: you think so
# 57        CLR: oh I dont know hes quite a dude isnt he
# 58                           CLD: that Cochoran guy is
# 59                                             CLD: uh
# 60                                            CLD: yep
# 61                                      CLR: I hope so
# 62                                           CLD: yeah
# 63     CLD: I mean I I dont believe him and its not ...
# 64                                       CLD: you know
# 65          CLD: which is all that he really has to do
# 66                                            CLR: yep
# 67                                            CLD: hmm
# 68                                            CLD: mmm
# 69                                                CLD:
# 70                                   CLR: so what else
# 71                                    CLR: is going on
# 72                                                CLD:
# 73     CLD: oh I thought actually you might be Rich ...
# Name: CLD: no way man , Length: 74, dtype: object
# 0                                                   F2:
# 1       F1: I dont know one minute Im seems were reco...
# 2       F2: maybe we can talk about how long the whol...
# 3                                             F1: maybe
# 4                                                   F2:
# 5       F1: I dont even know whether i want to be rec...
# 6                                                   F2:
# 7            F1: I guess if so many weirdos can hear it
# 8                              F2: we dont we dont care
# 9       F1: okay how how long can you do that theyve ...
# 10      F2: to this experiment they alter you with in...
# 11                                    F1: thats so cool
# 12      F2: So Im calling Ariel for her birthday for ...
# 13                                                  F1:
# 14                                             F2: what
# 15                            F1: well how do you do it
# 16      F2: let me give you the number write it down ...
# 17          F1: okay Im writing it down I want to do it
# 18      F2: okay were being recorded about the experi...
# 19                                                  F1:
# 20                            F2: uhm One eight hundred
# 21                                         F1: mmm hmmm
# 22               F2: maybe thats part of the experiment
# 23                                                  F1:
# 24                             F2: Three three eight oh
# 25                                    F1: You must have
# 26                                   F2: three eight oh
# 27                                             F1: uhuh
# 28                      F2: wait let me double check it
# 29      F1: whats going on half an hour talking about...
#                              ...
# 83                                              F2: uuh
# 84      F1: wanting to see it Saturday night And and ...
# 85             F2: yeah I dont work hard enough Ive Ive
# 86      F1: no because my classes are insane Ijust fi...
# 87                                 F2: no you wrote one
# 88      F1: Oh Okay Im so excited about it I wrote I ...
# 89                                           F2: uh huh
# 90      F1: basically you can do anything its for thi...
# 91                                      F2: theyll hear
# 92                              F2: theyre recording us
# 93            F2: Im just kidding Go on Im just kidding
# 94                F1: and now Im going to illustrate it
# 95                                             F2: uhuh
# 96      F1: and Ive got so much done like I sat at my...
# 97                                              F2: wow
# 98      F1: it was awesome like it totally reminded m...
# 99                      F2: did you give this into your
# 100                                            F1: what
# 101                      F2: did you give it in already
# 102                                      F1: no not yet
# 103                F2: oh this is part of it okay I see
# 104                         F1: yeah this is part of it
# 105     F2: what about these like fourth grade when m...
# 106       F1: you x you know Im not always talked about
# 107                                          F2: really
# 108     F1: yeah see they they were like best friends...
# 109                                   F2: yeah whatever
# 110                                            F1: what
# 111     F2: they werent best friends when we were lit...
# 112     F1: yeah when they were little he just Its so...
# Name: F1: can you hear that , Length: 113, dtype: object
# 0                                      A: Oh that sucks
# 1                                            B: Yeah So
# 2                           A: Damn you had five finals
# 3                                               B: Yeah
# 4                       A: I only have I have three man
# 5           B: Yeah well I had one final this last week
# 6       B: uh one was a takehome and so I just only h...
# 7                                          A: But still
# 8       B: The takehome was uh I was up till like fou...
# 9                                          A: Oh really
# 10        B: Yeah it was due eleven oclock this morning
# 11                          A: was it computer thing or
# 12                  B: Uh not really computer thing but
# 13                                             A: great
# 14                                                B: so
# 15                                         A: thats fun
# 16                                                   B:
# 17                          A: When you going home then
# 18                                         B: Uh Sunday
# 19                    A: then how long you have off for
# 20                      B: Uh till like january seventh
# 21      A: oh yeah yeah that sounds yeah lot of my fr...
# 22                                             B: Um hm
# 23            A: so whenever youre done with finals you
# 24                                              B: yeah
# 25       A: and then we get off until january fifteenth
# 26                     B: ok yeah that sounds like yeah
# 27                                              A: like
# 28      B: the classes start around well about the te...
# 29      A: yeah I mean my friend has shes going to ja...
#                              ...
# 585     A: So were not going to be able to do the sho...
# 586                                                  B:
# 587     A: I dont know I think theyre going to force ...
# 588                                                  B:
# 589                            A: I quit piano and like
# 590                                             B: Yeah
# 591       A: its hard just messing around with you know
# 592                                           B: c yeah
# 593                             A: You know it doesnt c
# 594          B: aa gg glad I never really got into that
# 595                                                  A:
# 596                                                  B:
# 597                                  A: youre lucky man
# 598                                             A: like
# 599     B: yeah I pretty much refused steadfastly fro...
# 600     A: And T J got a lot of crap he gets a lot of...
# 601                                             B: Yeah
# 602               A: Like a yeah shes the most and like
# 603     B: Well she likes to show him off because hes...
# 604                                     A: Yeah oh jeez
# 605                                                  B:
# 606                                            A: Oh Gd
# 607                                               B: So
# 608                       A: Dont even remind me I know
# 609                                                  B:
# 610      A: Hes great yeah He like he started up guitar
# 611                                             B: Yeah
# 612                                        B: Oh did he
# 613                                           A: Um hmm
# 614                                             B: Jeez
# Name: B: Yeah three subjects I got done with now I got two subjects left , Length: 615, dtype: object
# 0                              F1: I guess were allright
# 1                                                    F2:
# 2                                                  F2: i
# 3                F1: i were being publically distributed
# 4                                      F1: whatever that
# 5                                                 F2: ah
# 6                                                  F1: i
# 7          F1: I dont think itll be all that interesting
# 8                                               F1: i um
# 9                      F1: did Karen explain this to you
# 10                         F2: no I havent Talked to her
# 11                                           F1: oh okay
# 12                F1: its something to do with linguists
# 13                                                   F1:
# 14                F1: its a research programof some kind
# 15                                                F2: ah
# 16                                          F1: whatever
# 17                                                   F2:
# 18                                 F1: any way excuse me
# 19       F1: i were going down to New Jersey today to ...
# 20                                          F1: i and um
# 21                           F1: so Im going to tell him
# 22                                   F1: i that you know
# 23       F1: well well that that the end of May would ...
# 24                                              F2: yeah
# 25                                            F1: i okay
# 26                                        F2: thats fine
# 27                                  F1: that sounds good
# 28       F1: i Im also going to try to convince them t...
# 29          F2: i well I think I think thats a good idea
#                               ...
# 1008                                                 F2:
# 1009              F2: i we have to get our butts in gear
# 1010                                     F2: i as far as
# 1011                                              F1: oh
# 1012                                  F2: retirement and
# 1013                                                 F1:
# 1014                                           F1: right
# 1015                F1: i cause dad and I were wondering
# 1016                        F1: i you know we we have um
# 1017                    F1: i uh if we should remortgage
# 1018     F1: and I dont know whats the best thing for ...
# 1019                                        F1: you know
# 1020                                            F2: yeah
# 1021                F1: for our for ours either you know
# 1022             F1: i because if we remortgage it costs
# 1023                      F1: I think it costs money and
# 1024       F1: i I dont want it to go for too many years
# 1025     F1: you know I want it to be short term bing ...
# 1026                                            F2: yeah
# 1027     F1: we we havent made any major decisions eit...
# 1028                                            F2: yeah
# 1029     F2: i we we have some money that we need to d...
# 1030                                         F1: oh okay
# 1031                                        F2: you know
# 1032         F1: is that left over from your inheritance
# 1033                                          F2: i yeah
# 1034                                          F1: uh huh
# 1035                                          F2: and um
# 1036                                                 F2:
# 1037                                         F2: they uh
# Name:  F1: okay , Length: 1038, dtype: object
# 0                                          F1: hi there
# 1                                                F2: hi
# 2           F1: I didnt know they were going to do that
# 3                                              F2: yeah
# 4         F2: one of my clients got me a Christmas gift
# 5                        F2: Im sure you get them right
# 6                        F1: um not that often actually
# 7                                F2: it it kind of like
# 8                            F2: it sort of bo thers me
# 9       F2: cause you know that youre not supposed to...
# 10                        F2: but it was like this this
# 11                  F1: I think little gifts youre fine
# 12      F1: like Ive gotten cookies and stuff like that
# 13                                   F2: yeah well with
# 14                 F1: I wouldnt accept something major
# 15                           F2: it wasnt a major thing
# 16      F2: but what it was is it was a pair of earri...
# 17                                 F1: oh no definitely
# 18        F2: but its really but its really nice though
# 19      F2: its like these really cute silver like da...
# 20                           F2: and like this necklace
# 21                               F2: and I mean I tried
# 22      F1: no I think if kid clients make you things...
# 23                    F2: well it was a kid client yeah
# 24      F2: but still it was so nice I felt so awkwar...
# 25               F2: you really shouldnt have done this
# 26                                       F2: I said but
# 27                         F2: oh its so nice thank you
# 28               F2: cause I didnt want her to feel bad
# 29                              F2: and then I told her
#                              ...
# 318                         F1: cause um he had taken a
# 319                                                 F1:
# 320                                                 F1:
# 321                                             F2: mhm
# 322                                 F1: and Martys like
# 323                  F1: well I have to go shopping now
# 324                               F1: what do you think
# 325                                                 F2:
# 326                                F1: so I felt better
# 327     F2: well I um like for the neu rolo gist I wo...
# 328     F2: I I bought her like an assortment of like...
# 329                                            F1: m hm
# 330                  F2: that I got like at a Sams Club
# 331                                           F1: right
# 332           F2: its really nice they liked that a lot
# 333                       F2: and then for my secretary
# 334                               F1: yeah I like those
# 335     F2: one of the one of the secretaries in one ...
# 336                          F2: she makes gift baskets
# 337                                         F1: oh cool
# 338                                                 F2:
# 339                     F1: thats a good person to know
# 340                                            F2: what
# 341                     F1: thats a good person to know
# 342     F2: oh I told her Im going to be her biggest ...
# 343     F2: cause I can even give her the stuff and s...
# 344                        F2: like I can buy the stuff
# 345                                         F1: oh cool
# 346     F2: and then give it to her and shell arrange...
# 347     F2: but I got my secretary this bas ket with ...
# Name:  F2: hello , Length: 348, dtype: object
# 0                                                 F1: my
# 1        F2: does that mean theyll pay for this call p...
# 2                      F1: I was do ingall these studies
# 3                                                 F1: na
# 4                                                 F2: oh
# 5                                                    F1:
# 6        F2: I was hoping that theyd pay for this phon...
# 7                                             F1: uh huh
# 8        F2: I was hop ing that means they pay for the...
# 9                                           F1: could be
# 10                                F1: I have to find out
# 11                             F1: maybe theyre doing it
# 12                                 F1: they told me this
# 13                                      F1: no Ill do it
# 14       F1: no I think at the end of the month they s...
# 15                                              F2: good
# 16                          F1: just for being in it and
# 17                                      F1: the big deal
# 18                             F1: Im not doing anything
# 19                                      F1: its not hard
# 20                                     F1: so Ma zel tov
# 21                                  F1: I was so excited
# 22                                    F1: when called me
# 23                                              F2: yeah
# 24                       F2: well I told him to call you
# 25                                    F1: are you ear ly
# 26                                              F1: late
# 27                    F2: um well two days early I guess
# 28                            F2: thats not really early
# 29                                F1: yeah thats not bad
#                               ...
# 1390                      F1: ay getting the other phone
# 1391                                       F1: all right
# 1392                                            F2: okay
# 1393                                F1: refuah shleimasy
# 1394                        F2: well thanks for call ing
# 1395                            F1: or actually whatever
# 1396                   F1: feel good hope the babys okay
# 1397                                     F2: and this is
# 1398                                          F1: and uh
# 1399                                            F2: yeah
# 1400       F2: this is like way better than a Cl section
# 1401                                            F1: yeah
# 1402                               F2: even with this uh
# 1403        F1: I ll speak to you then when you get home
# 1404                                       F2: vacuuming
# 1405                                            F2: yeah
# 1406            F2: well hopefully Ill be home this week
# 1407                             F2: Ill give you a call
# 1408                                           F1: a hah
# 1409                                      F1: okay great
# 1410     F2: if the baby doesnt come home then Ill be ...
# 1411                                              F1: oh
# 1412                                                 F1:
# 1413                                           F2: right
# 1414                                       F1: feel good
# 1415                                           F2: o kay
# 1416                                         F1: than ks
# 1417                                       F2: all right
# 1418                                             F2: bye
# 1419                                         F1: bye bye
# Name:  F1: sorry , Length: 1420, dtype: object
# 0                                         M1: you there
# 1                                              M2: okay
# 2                                    M2: what what what
# 3                                                   M2:
# 4                                                   M1:
# 5                                                   M1:
# 6                                   M2: baruch hashemsy
# 7                                                   M1:
# 8                            M2: coming this week to uh
# 9                                              M1: yeah
# 10                 M1: youre coming in for your nephews
# 11                                   M2: yeah were just
# 12                                                  M1:
# 13                          M2: coming in Tuesday night
# 14                                             M1: yeah
# 15                  M2: well come back Thursday already
# 16                               M1: ah hah well hashem
# 17                                        M2: yeah good
# 18                                  M2: hows everything
# 19                                  M1: baruch hashemsy
# 20                        M2: you living by your mother
# 21                                 M1: not by my mother
# 22            M1: we have the apartment above my mother
# 23                             M2: oh oh oh oh oh oh oh
# 24                                 M1: not by my mother
# 25                                            M2: I see
# 26                                                  M1:
# 27                                           M2: ah hah
# 28                M1: andshe had an apartment available
# 29                                         M2: oh I see
#                              ...
# 115                                            M1: yeah
# 116                                                 M1:
# 117                       M2: so they owe you more then
# 118            M1: yeah but I had to I had to out there
# 119                                                 M2:
# 120                                        M2: yeah you
# 121      M1: otherwise I have to or I have to go to the
# 122                                M1: end up being the
# 123                                       M2: youre not
# 124         M1: I end up being the on some of the money
# 125                                          M2: ah hah
# 126                                                 M2:
# 127                                            M1: yeah
# 128                                          M2: ah hah
# 129                            M2: well let me tell you
# 130                                        M1: cause it
# 131                       M1: well it ended up in court
# 132                          M2: it would it would have
# 133                                            M1: yeah
# 134                   M2: oh thats how strong they were
# 135                           M1: thats how strong what
# 136           M2: thats how strong they would have gone
# 137                               M1: it seems that way
# 138     M1: I mean chances arewe would have ended up ...
# 139              M1: I probably would have court anyway
# 140                                            M2: m hm
# 141                                            M2: m hm
# 142                                 M1: but school also
# 143                                                 M1:
# 144                                            M2: m hm
# Name:  M1: okay , Length: 145, dtype: object
# 0                                                    F1:
# 1                                    F2: put it on tv or
# 2                                            F1: quickly
# 3                                           F2: anything
# 4                                           F1: what the
# 5                      F1: oh my god I have another call
# 6                                             F2: oh god
# 7                      F1: jesus christ hold on a second
# 8                                                    F1:
# 9                                               F2: okay
# 10                                                   F1:
# 11       F2: were be ing re cor ded for e du ca tional...
# 12                                          F2: purposes
# 13                           F2: and so its free for her
# 14                                                   F2:
# 15                            F2: what I dont understand
# 16       F2: she has a free so she can she can call lo...
# 17       F2: theyre using it for ed u ca tional pur po...
# 18            F2: that noise is making me really nervous
# 19                                              F1: Maya
# 20                                              F2: yees
# 21                                                 F2: s
# 22                 F1: you would nt believe who that was
# 23                                               F2: who
# 24                                            F1: Rachel
# 25                                         F2: oh my god
# 26                                         F1: I know ow
# 27                      F2: does she have free calls too
# 28                                          F1: no no no
# 29       F1: shes just she was just call ing cause I c...
#                               ...
# 1272                 F2: so I wouldnt mind working there
# 1273                           F1: oh that would be cool
# 1274      F2: and what else I was thinking maybe Daytons
# 1275           F1: m hm youve got some connections there
# 1276                                        F2: well yes
# 1277                                                 F2:
# 1278                                             F1: wow
# 1279      F2: I would nt wanna work downtown Minneapolis
# 1280                                 F2: itstoo far away
# 1281                               F1: it is kind of far
# 1282                                      F2: so anyways
# 1283            F2: that is really my life in a nutshell
# 1284                    F2: I havent read any good books
# 1285                        F2: I started a good book um
# 1286                            F2: I havent finished it
# 1287                                       F1: what book
# 1288                        F2: The Feminine Face of God
# 1289                                               F1: m
# 1290               F2: yes I know it sounds very bizarre
# 1291                                                 F1:
# 1292                                         F2: but its
# 1293     F1: sounds like something D eb Jacobs might h...
# 1294                                         F2: n owu h
# 1295        F2: its the unfolding of the sacred in women
# 1296                                   F2: my mom had it
# 1297                                     F1: interesting
# 1298                                  F2: and its a bout
# 1299     F2: how women are better than men in all ways...
# 1300                                           F1: n duh
# 1301                                     F2: but it is I
# Name: F2: well if he keeps swearing all the time maybe then they wont , Length: 1302, dtype: object
# 0                                                F2: mhm
# 1                                                F1: hey
# 2                                                F2: hey
# 3                                                    F1:
# 4                                                  F1: i
# 5                                                 F2: ih
# 6                                  F1: Im working for uh
# 7                F1: this linguistics department at Penn
# 8                                                F2: mhm
# 9                                        F1: ih and they
# 10                      F1: record phone calls and stuff
# 11                                                   F1:
# 12                         F1: i and you get it for like
# 13              F1: I get a free free thirty minute call
# 14                                                   F1:
# 15                                                 F1: i
# 16                                               F2: wow
# 17                                F1: and twenty dollars
# 18                              F1: i but they record it
# 19              F1: and they use it for linguistic stuff
# 20                              F2: oh thats really neat
# 21                                                 F1: i
# 22       F1: but nobody knows who you are so dont worr...
# 23                                             F1: or me
# 24                   F1: like your names arent connected
# 25                                                   F2:
# 26                 F1: our names arent connected with it
# 27                               F1: so it doesnt matter
# 28                               F2: i so whats going on
# 29                F1: i so talk to me for thirty minutes
#                               ...
# 1399                   F1: is your man a medical student
# 1400                            F2: hes a dental student
# 1401                                F1: a dental student
# 1402                                            F2: m hm
# 1403          F1: Jesus christ your kids will be all set
# 1404                                          F2: I know
# 1405     F1: theyll be heal thy and and have straight ...
# 1406                                          F2: I know
# 1407                                  F2: Im all psyched
# 1408                                                 F1:
# 1409                                               F2: i
# 1410     F2: and his dad was a dentist from hed gradua...
# 1411                                                 F1:
# 1412                                F2: hes from bos ton
# 1413                                            F1: a ha
# 1414     F2: and hes got a really really thick Boston ...
# 1415                              F2: like its hilarious
# 1416                                    F2: like he says
# 1417      F2: I was talking about the heart and hes like
# 1418                      F2: i I have to study the haht
# 1419                                F2: and Im like what
# 1420     F2: its like a totally cant understand what h...
# 1421                                F2: i ah hes so cute
# 1422                          F1: a thick bos ton accent
# 1423                           F1: how can you not laugh
# 1424                         F2: oh I laugh all the time
# 1425                                                 F1:
# 1426                       F2: I totally make fun of him
# 1427                    F2: he sounds like such an idiot
# 1428                                               F1: i
# Name:  F1: Rick , Length: 1429, dtype: object
# 0                                             F1: hello
# 1                                                F2: mh
# 2                                                   F1:
# 3                                                   F2:
# 4                                  F1: did you hear her
# 5                                            F2: i yeah
# 6                                      F2: very clearly
# 7                                                   F1:
# 8                                                   F2:
# 9                                              F1: okay
# 10                                                  F2:
# 11                                             F2: i um
# 12                                          F2: I al so
# 13                          F2: I totally missed it out
# 14                                               F1: oh
# 15                   F1: well we called Eretz Yisraelsy
# 16                                       F2: thats good
# 17                        F1: but I never called the um
# 18                                        F1: the thing
# 19                                         F1: you know
# 20                                              F2: the
# 21            F1: i I never called in the United States
# 22                                            F2: right
# 23       F2: so they still are hav ing it available now
# 24                                                F1: i
# 25                              F2: you had to reap ply
# 26                                     F1: its the well
# 27                          F1: i its finished tomorrow
# 28                                           F2: uh huh
# 29                       F1: I mean by midnight tonight
#                              ...
# 768                                      F1: one second
# 769                                   F2: you dont know
# 770                                            F1: i Ur
# 771     F1: wheres that information about Judowicz that
# 772                                            F2: what
# 773     F1: cause it was Solly Lampert who called him...
# 774                               F1: he know them well
# 775                         F1: he wasnt going out then
# 776                                             F1: but
# 777                         F1: you got new information
# 778                                  F1: whats his name
# 779                  F1: did did you get his first name
# 780                                              F1: oy
# 781                       F1: I dont know how youd find
# 782                                       F2: what ever
# 783               F2: Ill ask him if he knows which son
# 784                                            F2: hell
# 785                                           F1: Yakov
# 786                                            F2: okay
# 787                                            F2: fine
# 788                            F2: Ill give them a buzz
# 789                           F1: okay Id appreciate it
# 790                                         F2: okayIll
# 791                 F2: i Ill let you know what he says
# 792                                            F1: okay
# 793                                            F2: okay
# 794                               F1: okay thanks a lot
# 795                                                 F2:
# 796                                         F2: bye bye
# 797                                          F1: byebye
# Name:  F2: hello , Length: 798, dtype: object

# %%
# import os
# import pandas
# from pandas import *
# import nltk, string, re, math, os, numpy, csv
# ##// no need for string if using new whitelist method

# INPUT_PATH = '/Users/nduran/Dropbox (ASU)/DA/DA_linguisticAlignment/working/ALIGN_DA_ANALYSIS/'
# # FILE_NAME = 'DA_transcripts_agreement.txt' ## ROUND 2
# FILE_NAME = 'DA_transcripts_disagreement.txt' ## ROUND 1

# ##// this is just to get the data prepped for the starting format in paper
# def get_unique(dataframe):
#     uniqueDyad = dataframe.dyadNumber.unique()
#     uniqueConvo = dataframe.convoCode.unique()
#     return uniqueDyad, uniqueConvo

# ##// this is just to get the data prepped for the starting format in paper
# def order_turns(df1,convo,dyad): 
#     dA1 = df1.loc[(df1['type'] == 1) & (df1['dyadNumber'] == int(dyad)) & (df1['convoCode'] == int(convo))]    
#     dA1 = dA1.sort_values(['begin'], ascending=[True])                
#     return dA1

# ##// this is just to get the data prepped for the starting format in paper
# def remove_fillers(dataframe):
# #     WHITELIST = set('abcdefghijklmnopqrstuvwxy ABCDEFGHIJKLMNOPQRSTUVWXYZ') # only include letters and spaces (no numbers, no punctuation, no apostrophes, etc.)
#     clean = []
#     for value in dataframe['content'].values:        
# #         pattern = re.compile('^[m]\s[mh]+\s+')
# #         clean1 = pattern.match(value)
# #         if clean1:
# #             print clean1.group(0)
            
# #         removefiller = re.sub('\*\w+\s[uhmo]+', ' ', value) ##new get rid of all two word sequences starting with an asterisk
# #         removefiller = re.sub('\*\w+\s', ' ', removefiller) ##new get rid of all words starting with an asterisk
# #         removefiller = re.sub('\*mm', ' ', removefiller) ##new weirdness for DA data
# #         removefiller = re.sub('Mm hm', ' ', removefiller) ##new weirdness for DA data
# #         removefiller = re.sub('Mm...', ' ', removefiller) ##new weirdness for DA data
                
# #         removefiller = re.sub('^[m]+\s[mh]+', ' ', removefiller) ##new start of string: get rid of all "m hm" or "mm hmm" sort of sequences
# #         removefiller = re.sub('^[m]\s[mh]+\s+', ' ', removefiller) ##new start of string: get rid of all "m hm" or "mm hmm" sort of sequences, but with trailing white spaces
        
# #         removefiller = re.sub('\s[m]+\s[mh]+', ' ', removefiller) ##new within string: get rid of all "m hm" or "mm hmm" sort of sequences
# #         removefiller = re.sub('\s[m]\s[mh]+\s+', ' ', removefiller) ##new within string: get rid of all "m hm" or "mm hmm" sort of sequences, but with trailing white spaces

# #         removefiller = " ".join(removefiller.split()) ##new            
        
# #         clean.append(removefiller)
#         clean.append(value) 
        
#     dataframe['cleantext'] = clean
#     dataframe = dataframe.iloc[:, [9,14]]
#     dataframe = dataframe.rename(columns={'speakerDeceive': 'participant', 'cleantext': 'content'})
#     return dataframe

# def removeNullLines(dataframe,minwords):     
#     utteranceLen = []
#     for value in dataframe['content'].values:
#         if isinstance(value,basestring):
#             utteranceLen.append(len(value.split(" "))) 
#         else:
#             utteranceLen.append(0)       
#     dataframe['utteranceLen'] = utteranceLen        
#     dataframe2 = dataframe.loc[(dataframe['utteranceLen'] != 0) & (dataframe['utteranceLen'] > int(minwords))]
# #     return dataframe2
#     return dataframe2.iloc[:, [0,1]]

# dataframe1=read_csv(INPUT_PATH + FILE_NAME, sep='\t',encoding='utf-8')
# [dya, conv] = get_unique(dataframe1)   
# for con in conv:
#     for dy in dya:
#         df2 = order_turns(dataframe1,con,dy)
#         if len(df2) > 0: 
            
#             deceptionconvo = df2['convoDeceive'].iloc[1]
#             roundconvo = df2['round'].iloc[1]
            
#             df3 = remove_fillers(df2)
# #             df4 = removeNullLines(df3,1)
#     #         df5 = AdjacentMerge(df4)
            
# #             outname = INPUT_PATH + "TRANSCRIPTS/" + str(dy) + "_" + str(roundconvo) + "-" + str(deceptionconvo) + "-" + str(con) + ".txt"
# #             df4.to_csv(outname,encoding='utf-8',index=False,sep='\t') 
# #             outname = INPUT_PATH + "TRANSCRIPTS/" + "dyad" + str(dy) + "_" + "cond" + str(roundconvo) + "-" + str(deceptionconvo) + "-" + str(con) + ".txt"
#             outname = INPUT_PATH + "TRANSCRIPTS/" + str(dy) + "_" + str(roundconvo) + "-" + str(deceptionconvo) + "-" + str(con) + ".txt"
#             df3.to_csv(outname,encoding='utf-8',index=False,sep='\t')
